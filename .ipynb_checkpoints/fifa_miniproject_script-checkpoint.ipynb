# %% [markdown]
# # FIFA2020 Mini-project

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import os

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Importing Data

# %%
#Function to import all the csv data from the dir you are in
def import_from_dir(current_dir):
    files_lst = os.listdir(current_dir)
    df = pd.DataFrame()
    for file in files_lst:
        if file.endswith('.csv'):
            #attaching an empty dataframe to the df that wer read
            data = pd.read_csv(current_dir + file)
            df = pd.concat([df, data])
            df = df.drop_duplicates()
    return df

# %%
current_dir = './'
files_lst = os.listdir(current_dir)
#display(files_lst)
fifa_df=pd.read_csv(current_dir + files_lst[2]).set_index('ID', drop=True)
uefa_df=pd.read_csv(current_dir + files_lst[0],sep=';',decimal=',',na_values="-")

# %% [markdown]
# ## Data cleaning

# %%
def col_names_std(df):
    import pandas as pd
    import numpy as np
    df.columns = [df.columns[i].lower().replace(' ','_') for i in range(len(df.columns))]
    return df

fifa_df=col_names_std(fifa_df)
uefa_df=col_names_std(uefa_df).rename({'país': 'nationality'}, axis=1).set_index('pos', drop=True)
display(fifa_df.head())
uefa_df.head()
# Out:
#            name  age  ova            nationality           club  bov   bp  \
# ID
# 2   G. Pasquale   33   69                  Italy        Udinese   71  LWB
# 16  Luis García   37   71                  Spain      KAS Eupen   70   CM
# 27      J. Cole   33   71                England  Coventry City   71  CAM
# 36     D. Yorke   36   68  Trinidad &amp; Tobago     Sunderland   70   ST
# 41      Iniesta   36   81                  Spain    Vissel Kobe   82  CAM
#
#         position                                       player_photo  \
# ID
# 2             LM  https://cdn.sofifa.com/players/000/002/16_120.png
# 16    CM CAM CDM  https://cdn.sofifa.com/players/000/016/19_120.png
# 27  CAM RM RW LM  https://cdn.sofifa.com/players/000/027/16_120.png
# 36           NaN  https://cdn.sofifa.com/players/000/036/09_120.png
# 41        CM CAM  https://cdn.sofifa.com/players/000/041/20_120.png
#
#                                            club_logo  ...    cdm    rdm  \
# ID                                                    ...
# 2       https://cdn.sofifa.com/teams/55/light_60.png  ...  70+-1  70+-1
# 16    https://cdn.sofifa.com/teams/2013/light_60.png  ...   66+1   66+1
# 27    https://cdn.sofifa.com/teams/1800/light_60.png  ...   54+0   54+0
# 36     https://cdn.sofifa.com/teams/106/light_60.png  ...   65+0   65+0
# 41  https://cdn.sofifa.com/teams/101146/light_60.png  ...   73+3   73+3
#
#       rwb     lb   lcb    cb   rcb     rb    gk gender
# ID
# 2   71+-2  70+-1  69+0  69+0  69+0  70+-1  17+0   Male
# 16   62+1   60+1  60+1  60+1  60+1   60+1  17+1   Male
# 27   52+0   47+0  46+0  46+0  46+0   47+0  15+0   Male
# 36   56+0   57+0  51+0  51+0  51+0   57+0  22+0   Male
# 41   70+3   67+3  64+3  64+3  64+3   67+3  17+3   Male
#
# [5 rows x 106 columns]
#                    club nationality  15/16  16/17  17/18  18/19  19/20   pts   \
# pos
# 1     FC Bayern München         GER   22.0   29.0   20.0   36.0   27.0  134.0
# 2        Real Madrid CF         ESP   33.0   32.0   19.0   17.0   26.0  127.0
# 3    Manchester City FC         ENG   18.0   22.0   25.0   25.0   35.0  125.0
# 4          FC Barcelona         ESP   23.0   25.0   30.0   24.0   20.0  122.0
# 5              Juventus         ITA   33.0   23.0   21.0   22.0   21.0  120.0
#
#        fed
# pos
# 1    14.714
# 2    19.571
# 3    20.113
# 4    19.571
# 5    15.087

# %%
fifa_df.info()
fifa_df.isna().sum().value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17125 entries, 2 to 259105
# Columns: 106 entries, name to gender
# dtypes: float64(10), int64(44), object(52)
# memory usage: 14.0+ MB
# 0        89
# 58        8
# 7         2
# 23        2
# 89        2
# 413       1
# 423       1
# 16215     1
# dtype: int64

# %% [markdown]
# ### Decision: Drop rows with NaN from fifa_df
# There are too many rows with at least 1 NaN. Dropping all NaNs will reduce the DF too much.
# We decide to first keep those columns that are relevant for the analysis.

# %%
##We select those FIFA attributes that are relevant for the model.

#The categories can be found here:
#https://fifauteam.com/fifa-20-attributes-guide/

#From all the categories, we select as 'offensive' those attributes corresponding to Pace, Dribbling, Shooting and Physical.

#The defensive categories are Defending and Passing.

#We also include the best position (bp) in the model

general=['name','age','club','bp']

offensive=['acceleration','sprint_speed','agility','balance','ball_control','composure','dribbling',
                 'reactions','finishing','long_shots', 'penalties','positioning','shot_power','volleys', 'aggression',
                 'jumping','stamina','strength']
defensive=['heading_accuracy', 'interceptions', 'marking', 'sliding_tackle', 'standing_tackle', 'crossing','curve','long_passing', 'short_passing','vision']

# %%
fifa_df_clean=fifa_df[(general+offensive+defensive)]
fifa_df_clean
# Out:
#                    name  age           club   bp  acceleration  sprint_speed  \
# ID
# 2           G. Pasquale   33        Udinese  LWB            68            74
# 16          Luis García   37      KAS Eupen   CM            56            50
# 27              J. Cole   33  Coventry City  CAM            48            42
# 36             D. Yorke   36     Sunderland   ST            59            62
# 41              Iniesta   36    Vissel Kobe  CAM            61            56
# ...                 ...  ...            ...  ...           ...           ...
# 259088       A. Medioub   22     CD Tondela   CB            52            55
# 259090       W. Rickard   18        Burnley  CAM            61            63
# 259091       C. Barrett   18        Burnley   RB            66            61
# 259101   J. Gazibegović   20  SK Sturm Graz   RB            72            70
# 259105  Pablo Rodríguez   18          Lecce   ST            68            72
#
#         agility  balance  ball_control  composure  ...  heading_accuracy  \
# ID                                                 ...
# 2          68.0     68.0            71        NaN  ...                59
# 16         62.0     72.0            71       79.0  ...                61
# 27         71.0     75.0            78        NaN  ...                41
# 36          NaN      NaN            77        NaN  ...                60
# 41         79.0     75.0            90       89.0  ...                54
# ...         ...      ...           ...        ...  ...               ...
# 259088     46.0     42.0            56       46.0  ...                66
# 259090     52.0     68.0            54       46.0  ...                50
# 259091     54.0     68.0            47       43.0  ...                53
# 259101     74.0     77.0            57       54.0  ...                52
# 259105     59.0     65.0            55       57.0  ...                59
#
#         interceptions  marking  sliding_tackle  standing_tackle  crossing  \
# ID
# 2                69.0       70            69.0               69        75
# 16               71.0       70            40.0               43        68
# 27               39.0       35            30.0               34        80
# 36               70.0       34             NaN               41        54
# 41               70.0       68            56.0               57        75
# ...               ...      ...             ...              ...       ...
# 259088           58.0       61            66.0               71        35
# 259090           50.0       34            56.0               42        50
# 259091           55.0       55            54.0               54        55
# 259101           58.0       57            61.0               62        62
# 259105           11.0       12            11.0               12        32
#
#         curve  long_passing  short_passing  vision
# ID
# 2        65.0            69             71    66.0
# 16       79.0            71             76    73.0
# 27       84.0            69             77    74.0
# 36        NaN            64             80     NaN
# 41       80.0            83             90    93.0
# ...       ...           ...            ...     ...
# 259088   26.0            34             47    29.0
# 259090   42.0            61             64    53.0
# 259091   43.0            36             42    45.0
# 259101   43.0            57             60    56.0
# 259105   45.0            30             45    50.0
#
# [17125 rows x 32 columns]

# %%
fifa_df_clean.dropna(axis=0, how='any', inplace=True)
fifa_df_clean
# Out:
#                    name  age           club   bp  acceleration  sprint_speed  \
# ID
# 16          Luis García   37      KAS Eupen   CM            56            50
# 41              Iniesta   36    Vissel Kobe  CAM            61            56
# 80         E. Belözoğlu   38  Fenerbahçe SK   CM            54            36
# 330            R. Keane   35      LA Galaxy   CF            69            68
# 1179          G. Buffon   42       Juventus   GK            37            30
# ...                 ...  ...            ...  ...           ...           ...
# 259088       A. Medioub   22     CD Tondela   CB            52            55
# 259090       W. Rickard   18        Burnley  CAM            61            63
# 259091       C. Barrett   18        Burnley   RB            66            61
# 259101   J. Gazibegović   20  SK Sturm Graz   RB            72            70
# 259105  Pablo Rodríguez   18          Lecce   ST            68            72
#
#         agility  balance  ball_control  composure  ...  heading_accuracy  \
# ID                                                 ...
# 16         62.0     72.0            71       79.0  ...                61
# 41         79.0     75.0            90       89.0  ...                54
# 80         67.0     81.0            81       80.0  ...                43
# 330        77.0     83.0            84       86.0  ...                63
# 1179       55.0     49.0            28       70.0  ...                13
# ...         ...      ...           ...        ...  ...               ...
# 259088     46.0     42.0            56       46.0  ...                66
# 259090     52.0     68.0            54       46.0  ...                50
# 259091     54.0     68.0            47       43.0  ...                53
# 259101     74.0     77.0            57       54.0  ...                52
# 259105     59.0     65.0            55       57.0  ...                59
#
#         interceptions  marking  sliding_tackle  standing_tackle  crossing  \
# ID
# 16               71.0       70            40.0               43        68
# 41               70.0       68            56.0               57        75
# 80               62.0       65            60.0               65        80
# 330              34.0       28            17.0               26        68
# 1179             28.0       13            11.0               11        13
# ...               ...      ...             ...              ...       ...
# 259088           58.0       61            66.0               71        35
# 259090           50.0       34            56.0               42        50
# 259091           55.0       55            54.0               54        55
# 259101           58.0       57            61.0               62        62
# 259105           11.0       12            11.0               12        32
#
#         curve  long_passing  short_passing  vision
# ID
# 16       79.0            71             76    73.0
# 41       80.0            83             90    93.0
# 80       83.0            85             84    85.0
# 330      82.0            63             81    82.0
# 1179     20.0            35             37    50.0
# ...       ...           ...            ...     ...
# 259088   26.0            34             47    29.0
# 259090   42.0            61             64    53.0
# 259091   43.0            36             42    45.0
# 259101   43.0            57             60    56.0
# 259105   45.0            30             45    50.0
#
# [16687 rows x 32 columns]

# %%
uefa_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 428 entries, 1  to 428
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   club         428 non-null    object
#  1   nationality  428 non-null    object
#  2   15/16        232 non-null    float64
#  3   16/17        236 non-null    float64
#  4   17/18        237 non-null    float64
#  5   18/19        237 non-null    float64
#  6   19/20        237 non-null    float64
#  7    pts         428 non-null    float64
#  8    fed         428 non-null    float64
# dtypes: float64(7), object(2)
# memory usage: 33.4+ KB

# %%
uefa_df.columns
# Out:
# Index(['club', 'nationality', '15/16', '16/17', '17/18', '18/19', '19/20',
#        ' pts ', ' fed '],
#       dtype='object')

# %% [markdown]
# ### We will only keep the values for the 19/20 season for the model. In fact, those will be the ones we use as target. So, we will have a DF with club, nationality and 19/20.

# %%
uefa_df_clean=uefa_df[['club', 'nationality',uefa_df.columns[7]]].dropna(axis=0, how='any')
points=uefa_df.columns[7]
uefa_df_clean
# Out:
#                     club nationality    pts
# pos
# 1      FC Bayern München         GER  134.00
# 2         Real Madrid CF         ESP  127.00
# 3     Manchester City FC         ENG  125.00
# 4           FC Barcelona         ESP  122.00
# 5               Juventus         ITA  120.00
# ...                  ...         ...     ...
# 424         Llandudno FC         WAL    0.25
# 424            FK Bokelj         MNE    0.25
# 426          FCI Tallinn         EST    0.75
# 427      UE Santa Coloma         AND    0.50
# 428          FC Lusitans         AND    0.25
#
# [428 rows x 3 columns]

# %% [markdown]
# ## EDA

# %%
summary = fifa_df_clean.describe().T
summary['iqr'] = summary['75%']-summary['25%'] #addition of the iqr -inter quantile range- column
summary = summary.apply(lambda x: round(x, 2))
display(summary)
# Out:
#                     count   mean    std   min   25%   50%   75%   max   iqr
# age               16687.0  25.15   4.85  16.0  21.0  25.0  29.0  53.0   8.0
# acceleration      16687.0  65.51  14.65  12.0  58.5  68.0  75.0  97.0  16.5
# sprint_speed      16687.0  65.51  14.42  11.0  59.0  68.0  75.0  96.0  16.0
# agility           16687.0  64.64  14.38  14.0  57.0  67.0  75.0  96.0  18.0
# balance           16687.0  64.71  14.03  17.0  57.0  67.0  75.0  97.0  18.0
# ball_control      16687.0  60.55  15.85   5.0  57.0  64.0  70.0  96.0  13.0
# composure         16687.0  59.94  11.75  12.0  53.0  61.0  68.0  96.0  15.0
# dribbling         16687.0  57.80  18.05   5.0  53.0  63.0  70.0  96.0  17.0
# reactions         16687.0  62.84   8.99  24.0  57.0  63.0  69.0  95.0  12.0
# finishing         16687.0  47.87  19.38   3.0  33.0  52.0  63.0  95.0  30.0
# long_shots        16687.0  49.00  19.02   4.0  35.0  53.0  64.0  94.0  29.0
# penalties         16687.0  50.02  15.57   7.0  40.0  51.0  61.0  92.0  21.0
# positioning       16687.0  52.26  19.07   2.0  43.0  57.0  66.0  95.0  23.0
# shot_power        16687.0  59.63  13.31  12.0  50.0  61.0  70.0  95.0  20.0
# volleys           16687.0  44.86  17.67   4.0  32.0  46.0  58.0  90.0  26.0
# aggression        16687.0  56.89  17.01   9.0  45.0  60.0  70.0  96.0  25.0
# jumping           16687.0  65.17  11.91  22.0  58.0  66.0  73.0  95.0  15.0
# stamina           16687.0  63.42  15.30  11.0  56.0  66.0  74.0  97.0  18.0
# strength          16687.0  65.28  12.59  16.0  58.0  66.0  74.0  97.0  16.0
# heading_accuracy  16687.0  53.48  16.90   5.0  46.0  57.0  65.0  93.0  19.0
# interceptions     16687.0  46.97  20.82   4.0  26.0  53.0  65.0  93.0  39.0
# marking           16687.0  47.30  20.11   3.0  30.0  52.0  64.0  94.0  34.0
# sliding_tackle    16687.0  46.10  21.15   6.0  25.0  52.0  64.0  95.0  39.0
# standing_tackle   16687.0  48.28  21.45   5.0  28.0  55.0  66.0  93.0  38.0
# crossing          16687.0  51.52  17.85   6.0  40.0  56.0  65.0  94.0  25.0
# curve             16687.0  49.45  18.14   4.0  37.0  51.0  64.0  94.0  27.0
# long_passing      16687.0  54.22  14.84   9.0  45.0  57.0  65.0  93.0  20.0
# short_passing     16687.0  60.43  13.92   7.0  56.0  63.0  69.0  94.0  13.0
# vision            16687.0  55.36  13.67  10.0  46.0  57.0  65.0  95.0  19.0

# %% [markdown]
# ### Decision: aggregate the stats of players in the same club. The mean is a good aggregation function.
#
# ### Extra analysis: instead of aggregating all the offensive and defensive stats together, aggregate separately as different columns

# %%
grouped_fifa=fifa_df_clean.groupby('club').mean()

# %%
fifa_uefa=grouped_fifa.merge(uefa_df_clean,how='inner', on='club').drop(labels='nationality', axis=1)
fifa_uefa.sort_values(by=points, ascending=False)

#We decided to merge directly without standardization of the club names, due to time constraints.
# Out:
#                     club        age  acceleration  sprint_speed    agility  \
# 22     FC Bayern München  25.875000     68.375000     68.500000  66.791667
# 20          FC Barcelona  23.756757     70.783784     69.918919  70.891892
# 53              Juventus  26.500000     67.631579     69.631579  66.605263
# 62     Manchester United  24.350000     67.375000     69.375000  69.175000
# 70   Paris Saint-Germain  25.941176     69.176471     69.058824  72.882353
# ..                   ...        ...           ...           ...        ...
# 50       Heracles Almelo  22.800000     66.150000     63.850000  63.950000
# 108       Zagłębie Lubin  24.111111     59.666667     61.888889  61.333333
# 80           SC Freiburg  25.034483     61.068966     62.551724  63.724138
# 94       Strømsgodset IF  22.136364     67.863636     67.500000  62.863636
# 91        Stabæk Fotball  21.950000     69.350000     68.750000  67.400000
#
#        balance  ball_control  composure  dribbling  reactions  ...  \
# 22   66.791667     72.416667  73.791667  67.625000  80.791667  ...
# 20   69.513514     72.189189  72.216216  69.297297  74.189189  ...
# 53   65.868421     70.289474  72.105263  68.763158  75.447368  ...
# 62   65.925000     67.600000  71.400000  64.350000  74.100000  ...
# 70   70.500000     71.029412  73.117647  67.705882  74.647059  ...
# ..         ...           ...        ...        ...        ...  ...
# 50   59.850000     60.600000  57.000000  56.400000  58.450000  ...
# 108  63.111111     54.111111  57.777778  53.555556  58.777778  ...
# 80   63.482759     60.586207  57.931034  56.551724  68.827586  ...
# 94   64.727273     57.727273  55.181818  54.863636  57.500000  ...
# 91   69.650000     58.150000  56.500000  56.900000  56.850000  ...
#
#      interceptions    marking  sliding_tackle  standing_tackle   crossing  \
# 22       60.250000  58.000000       57.583333        60.291667  63.000000
# 20       51.378378  53.162162       50.297297        53.432432  59.972973
# 53       59.605263  60.578947       58.605263        61.263158  59.473684
# 62       57.825000  57.475000       54.450000        57.800000  58.600000
# 70       58.029412  55.764706       54.882353        58.264706  60.823529
# ..             ...        ...             ...              ...        ...
# 50       41.750000  44.400000       43.400000        45.950000  46.900000
# 108      39.555556  44.111111       39.444444        43.333333  49.333333
# 80       50.551724  49.862069       48.344828        50.275862  51.034483
# 94       44.409091  41.000000       42.272727        44.363636  47.227273
# 91       42.150000  40.350000       40.850000        42.200000  48.150000
#
#          curve  long_passing  short_passing     vision    pts
# 22   61.208333     68.500000      74.625000  70.166667  134.00
# 20   61.027027     67.108108      72.837838  68.594595  122.00
# 53   58.526316     64.315789      69.894737  64.842105  120.00
# 62   58.425000     64.250000      69.100000  65.450000  113.00
# 70   61.264706     65.735294      71.029412  67.323529  113.00
# ..         ...           ...            ...        ...     ...
# 50   46.350000     52.450000      58.400000  50.350000    1.00
# 108  49.666667     47.666667      54.333333  51.555556    1.00
# 80   48.793103     54.586207      62.172414  56.034483    1.00
# 94   46.136364     49.045455      56.136364  50.863636    0.50
# 91   49.050000     48.750000      55.200000  52.850000    0.25
#
# [110 rows x 31 columns]

# %%
for column in fifa_uefa.select_dtypes(np.number).columns:
    sns.distplot(fifa_uefa[column])
    plt.show()

# %% [markdown]
# #### All categories fall into a normal distribution with seemingly little to no outliers

# %%
# check the correlations
mask = np.zeros_like(fifa_uefa.corr())

mask[np.triu_indices_from(mask)] = True # optional, to hide repeat half of the matrix

fig, ax = plt.subplots(figsize=(20, 16))
ax = sns.heatmap(fifa_uefa.corr(), mask=mask, annot=True)
plt.show()

# %% [markdown]
# ### Some conclusions already:
# Interesting to see high correlation in attributes which can be clustered around the same 'skill subgroup'.
# Examples: 'ball control' is strongly correlated with short passing, curve or dribbling, but not so much with strength.
# Strength, conversely, is weakly correlated with any other attribute.

# %%
# covariance visualization
#sns.pairplot(grouped_fifa)

# %% [markdown]
# ## Preprocessing & Feature Engineering

# %%
def boxcox_transform(df):
    numeric_cols = df.select_dtypes(np.number).columns
    _ci = {column: None for column in numeric_cols} #it will first generate this dictionary
    for column in numeric_cols:
        #In this case, I need the confidence interval data
        # since i know any columns should take negative numbers, to avoid -inf in df
        df[column] = np.where(df[column]<=0, np.NAN, df[column]) #boxcox does not work with negatives
        df[column] = df[column].fillna(df[column].mean()) #I fill the nan's with the mean
        transformed_data, ci = stats.boxcox(df[column]) 
        df[column] = transformed_data
        _ci[column] = [ci] 
    return df, _ci

# %%
df, _ci = boxcox_transform(fifa_uefa)
df
# Out:
#                  club       age  acceleration  sprint_speed   agility  \
# 0          1. FC Köln  0.605846      4.251730      1.191745  1.666673
# 1     1. FSV Mainz 05  0.605790      4.264149      1.191890  1.668649
# 2                 AIK  0.606198      4.218622      1.190371  1.665249
# 3    AS Saint-Étienne  0.605776      4.285594      1.192287  1.671535
# 4          AZ Alkmaar  0.605473      4.248618      1.191234  1.672008
# ..                ...       ...           ...           ...       ...
# 105         Willem II  0.605626      4.309191      1.192879  1.671188
# 106    Wolfsberger AC  0.605365      4.330133      1.192444  1.670395
# 107  Yeni Malatyaspor  0.606232      4.320116      1.194436  1.670676
# 108    Zagłębie Lubin  0.605771      4.174439      1.190049  1.663612
# 109     Östersunds FK  0.605459      4.371826      1.195238  1.681437
#
#       balance  ball_control  composure  dribbling  reactions  ...  \
# 0    0.278287      4.657758   0.925552   1.470005   0.990152  ...
# 1    0.278287      4.660028   0.925690   1.471024   0.990313  ...
# 2    0.278287      4.578807   0.925729   1.463894   0.988776  ...
# 3    0.278287      4.686192   0.925611   1.472443   0.989314  ...
# 4    0.278287      4.649554   0.925955   1.464613   0.990263  ...
# ..        ...           ...        ...        ...        ...  ...
# 105  0.278287      4.578620   0.925075   1.466257   0.988444  ...
# 106  0.278287      4.654035   0.924496   1.464477   0.988158  ...
# 107  0.278287      4.673568   0.925679   1.476326   0.989998  ...
# 108  0.278287      4.485902   0.924916   1.461910   0.988119  ...
# 109  0.278287      4.612206   0.924426   1.470368   0.986729  ...
#
#      interceptions       marking  sliding_tackle  standing_tackle  crossing  \
# 0        86.850070  10827.744833     5470.249076      5160.762363  1.416372
# 1        94.768708  10193.672126     5546.080373      5151.079616  1.415152
# 2        90.454859   9126.494612     5299.082892      4833.139153  1.409702
# 3        89.203443   8756.704638     5364.232659      4759.169205  1.420298
# 4        83.918885   8913.593700     4906.612678      4624.946799  1.409361
# ..             ...           ...             ...              ...       ...
# 105      82.681960   8137.656303     5314.700418      4516.285413  1.415827
# 106      91.733020   8338.656081     6129.038699      4868.149195  1.410735
# 107      78.608382   7421.280868     3709.188869      3222.109841  1.416070
# 108      71.165936   7324.845989     3463.851918      3574.950194  1.410976
# 109      77.145184   7134.300315     3553.813782      3379.839189  1.410976
#
#         curve  long_passing  short_passing    vision      pts
# 0    1.228728      0.954876       5.273380  0.618238  1.343872
# 1    1.227410      0.955677       5.304920  0.618186  1.863016
# 2    1.229601      0.955238       5.236081  0.618246  1.721318
# 3    1.233159      0.956083       5.336866  0.618255  2.422237
# 4    1.229649      0.955694       5.265903  0.618282  2.865370
# ..        ...           ...            ...       ...       ...
# 105  1.227638      0.953888       5.163486  0.618120  0.682431
# 106  1.224676      0.954528       5.259118  0.618028  2.272859
# 107  1.231629      0.954799       5.248290  0.618238  0.682431
# 108  1.229036      0.952680       5.076683  0.618088  0.000000
# 109  1.227550      0.954359       5.170144  0.618153  2.187129
#
# [110 rows x 31 columns]

# %%
X = df.drop(['club',points], axis=1)
y = df[points]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## Analizing results

# %%
predictions = model.predict(X_test)

# %%
R2 = r2_score(y_test, predictions), 
MAE = mean_absolute_error(y_test, predictions), 
MSE = mean_squared_error(y_test, predictions, squared=False)

print('R2 =', R2)
print('MAE =', MAE)
print('MSE =', MSE)
# Out:
# R2 = (0.1496933419431694,)
# MAE = (0.9249953510433357,)
# MSE = 1.292281743780716

# %%
from scipy.special import inv_boxcox

predictions = inv_boxcox(predictions, _ci[points])
#MAE_t=mean_absolute_error(y_test, predictions)
#MSE_t=mean_squared_error(y_test, predictions, squared=False)
#print('MAE =', MAE_t)
#print('MSE =', MSE_t)

# %%
import math

results = pd.DataFrame()
results['true'] = inv_boxcox(y_test, _ci[points])
results['pred'] = predictions
results['resid'] = results.apply(lambda x: abs(x['true'] - x['pred']), axis=1)
results
# Out:
#       true          pred         resid
# 78    10.5           NaN           NaN
# 10    57.0           NaN           NaN
# 4     21.5           NaN           NaN
# 84    43.5           NaN           NaN
# 64    13.0           NaN           NaN
# 68     8.0  2.596068e+01  1.796068e+01
# 30    87.0           NaN           NaN
# 45    11.0           NaN           NaN
# 96    23.0           NaN           NaN
# 11    49.0           NaN           NaN
# 79    35.0           NaN           NaN
# 80     1.0           NaN           NaN
# 0      4.0           NaN           NaN
# 81     1.5           NaN           NaN
# 18     2.5  2.619463e+08  2.619463e+08
# 70   113.0           NaN           NaN
# 56     1.0           NaN           NaN
# 72    66.0           NaN           NaN
# 108    1.0           NaN           NaN
# 42     2.5  1.763210e+15  1.763210e+15
# 12     1.0  1.181797e+02  1.171797e+02
# 36     3.0           NaN           NaN
# 65     1.5           NaN           NaN
# 26     9.0           NaN           NaN
# 22   134.0           NaN           NaN
# 31    14.0           NaN           NaN
# 47     1.5           NaN           NaN
# 76     5.0           NaN           NaN
# 15     3.5           NaN           NaN
# 44    21.0           NaN           NaN
# 89    98.0           NaN           NaN
# 90     4.0           NaN           NaN
# 9     35.0           NaN           NaN

# %% [markdown]
# ### Conclusions:
# #### 1. R2 is too low. The dataset is too small for an appropriate trainging of the model.
# #### 2. We don't know if a linear regression is appropriate as a model.
